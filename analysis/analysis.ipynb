# %% [markdown]
# # Import Libraries & Data Sources

# %%
import pandas as pd

# %% [markdown]
# ## Minimal Confidence

# %% [markdown]
# ### Adjuster
# > everytime the sub detects the target, YOLO's confident and the following information should be returned for the sake of analysis
# 1. Current Z value (from shared memory)
# 2. Color of pixels (post-coinflip & per annotated photo)
# 3. Time of Day (Python library, should consider date due to seasons changing light levels at diff times)
